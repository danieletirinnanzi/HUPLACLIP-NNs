# %% [markdown]
# Test of AMP algorithm performance, adapted from Rudy's implementation in:
# https://colab.research.google.com/drive/1gntrdgJ1nfmGJLschTw__um2Bc4v77Ju?usp=sharing#scrollTo=PqffjBBRmOcL

# %%
# basic imports
import sys
import os
import numpy as np
import torch
import csv
import math
from scipy.stats import norm
from scipy import integrate
from typing import List, Tuple

# %%
# custom imports
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))

from src.utils import load_config

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Graphs generation functions (adapted)

# %% [markdown]
# Functions adapted from original ones because AMP algo expects a different input adjacency matrix (-1 and 1 for single tiles;
# 0 on the diagonal).

# %%
def plant_clique(graph, clique_size, graph_size):
    """
    Plants a clique of specified size within a given graph.

    Args:
        graph (torch.Tensor): Adjacency matrix representing the graph.
        size (int): Size of the clique to be planted.
        graph_size (int): Total number of nodes in the graph.

    Returns:
        torch.Tensor: Modified adjacency matrix with the planted clique.
    """
    # adding the planted clique to the adjacency matrix in the top left corner
    graph[:clique_size, :clique_size] = torch.ones(clique_size, clique_size)
    # creating a random permutation of the nodes
    random_permutation = torch.randperm(graph_size)
    # placing the rows and columns of the adjacency matrix according to the random permutation
    graph = graph[random_permutation[:, None], random_permutation]
    return graph


def generate_graph(
    on_off_label: int,
    graph_size: int,
    clique_size: int,
    p_correction_type: str,
    input_magnification: bool,
    p_nodes: float = 0.5,
) -> torch.Tensor:
    """
    Generates a graph with or without a planted clique with the specified correction.

    Args:
        on_off_label (int): Label indicating whether the graph will have a planted clique.
        graph_size (int): Number of nodes in the graph.
        clique_size (int): Size of the planted clique.
        p_correction_type (str): Type of p correction to apply.
        input_magnification (bool): Whether the input needs to be magnified. If True, the graph will be made a 2400x2400 tensor.
        p_nodes (float): Probability of an edge being present between two nodes.

    Raises:
        ValueError: If an invalid p_correction_type is provided.
        ValueError: If the clique size is too large for the graph size and the "p_reduce" correction type is used.

    Returns:
        torch.Tensor: Adjacency matrix representing a graph with the specified features.
    """

    # differentiating between the two types of correction:
    if p_correction_type == "p_increase":
        # (OLD CORRECTION) increasing the p value of the graph without the clique so that the average degree is matched between the two graphs

        # generating lower triangle of the adjacency matrix
        if on_off_label:
            # clique present
            adjacency_matrix = torch.bernoulli(
                p_nodes * torch.ones(graph_size, graph_size)
            )  # regular graph without clique
            # adding clique to adjacency matrix
            adjacency_matrix = plant_clique(adjacency_matrix, clique_size, graph_size)

        else:
            # clique not present
            p_corrected = p_nodes + (1 - p_nodes) * (
                (clique_size * (clique_size - 1)) / (graph_size * (graph_size - 1))
            )
            adjacency_matrix = torch.bernoulli(
                p_corrected * torch.ones(graph_size, graph_size)
            )

        # generating upper triangular matrix
        upper_triangular = torch.triu(adjacency_matrix)
        adjacency_matrix = upper_triangular + torch.transpose(upper_triangular, 0, 1)
        adjacency_matrix.fill_diagonal_(0)

    elif p_correction_type == "p_reduce":
        # (NEW CORRECTION) reducing the p value of the graph where the clique will be added

        # - making sure that the "p_reduce" corrected probability of association will be positive for requested clique size
        if clique_size > (
            (1 + math.sqrt(1 + 4 * p_nodes * graph_size * (graph_size - 1))) / 2
        ):
            clique_limit = int(
                (1 + math.sqrt(1 + 4 * p_nodes * graph_size * (graph_size - 1))) / 2
            )
            raise ValueError(
                f"Clique size {clique_size} in a graph of size {graph_size} leads to a negative corrected probability of association between nodes. Please choose a clique size smaller than {round(clique_limit)}"
            )

        # generating lower triangle of the adjacency matrix
        if on_off_label:
            # clique present (new correction acts on the reduction of p before adding the clique):
            # - computing the new probability of association
            p_corrected = (
                p_nodes * graph_size * (graph_size - 1)
                - clique_size * (clique_size - 1)
            ) / ((graph_size - clique_size) * (graph_size + clique_size - 1))
            # - creating the new random graph with the probability just computed
            adjacency_matrix = torch.bernoulli(
                p_corrected * torch.ones(graph_size, graph_size)
            )  # regular graph without clique, but with reduced p value
            # adding clique to adjacency matrix
            adjacency_matrix = plant_clique(adjacency_matrix, clique_size, graph_size)

        else:
            # clique not present (no need to correct)
            adjacency_matrix = torch.bernoulli(
                p_nodes * torch.ones(graph_size, graph_size)
            )

        # generating upper triangular matrix (MODIFIED FOR AMP ALGO COMPATIBILITY)
        upper_triangular = torch.triu(adjacency_matrix)
        adjacency_matrix = upper_triangular + torch.transpose(upper_triangular, 0, 1)
        adjacency_matrix.fill_diagonal_(0)

    else:
        raise ValueError(
            "Invalid p_correction_type. Must be either 'p_increase' or 'p_reduce'"
        )

    # transform zeros to -1s, keeping diagonal elements = 0
    adjacency_matrix[adjacency_matrix == 0] = -1
    adjacency_matrix.fill_diagonal_(0)

    return adjacency_matrix


def generate_batch_clique_sizes(allowed_clique_sizes, batch_size):
    """
    Generate the clique sizes for each graph in the batch (based on the allowed clique size values).

    Parameters:
    allowed_clique_sizes (np.ndarray): Allowed clique size values.
    batch_size (int): Size of the batch to generate.

    Returns:
    np.ndarray: Array of generated clique sizes for each graph in the batch.
    """
    # TESTING INPUT VALUES:
    if not isinstance(allowed_clique_sizes, np.ndarray):
        raise ValueError("allowed_clique_sizes must be a numpy array")
    if not isinstance(batch_size, int):
        raise ValueError("batch_size must be an integer")
    # if more than one clique size value is allowed, checking that last value of array is the smallest one:
    if len(allowed_clique_sizes) > 1:
        if min(allowed_clique_sizes) != allowed_clique_sizes[-1]:
            raise ValueError(
                "the last provided clique size value is not the smallest one: something might be wrong with the curriculum training procedure"
            )
    # END TESTING INPUT VALUES

    # probability of single clique size value is < 0.25:
    if 1 / len(allowed_clique_sizes) < 0.25:
        # - set minimum probability value for lowest clique size
        prob_lowest = 0.25
        # - calculate probability for remaining values (easier versions):
        prob_easier = (1 - 0.25) / (len(allowed_clique_sizes) - 1)
        # - define array of probabilities:
        allowed_clique_sizes_probs = np.full(len(allowed_clique_sizes) - 1, prob_easier)
        allowed_clique_sizes_probs = np.concatenate(
            (allowed_clique_sizes_probs, [prob_lowest])
        )

    # probability of single clique size value is >= 0.25
    else:
        # - simply define single prob value
        prob_each = 1 / len(allowed_clique_sizes)
        allowed_clique_sizes_probs = np.full(len(allowed_clique_sizes), prob_each)

    # Normalize the probabilities to ensure they sum to 1 (in case of rounding errors)
    allowed_clique_sizes_probs /= np.sum(allowed_clique_sizes_probs)

    # Generate the clique size array
    batch_clique_sizes = np.random.choice(
        allowed_clique_sizes, batch_size, p=allowed_clique_sizes_probs
    )

    return batch_clique_sizes


def generate_batch(
    number_of_graphs: int,
    graph_size: int,
    clique_size_array: List[int],
    p_correction_type: str,
    input_magnification: bool,
    p_clique: float = 0.5,
    p_nodes: float = 0.5,
) -> Tuple:
    """
    Generates batch of graphs. The size of each graph in the batch can be different, as well as the clique size.

    Args:
        number_of_graphs (int): Number of graphs in the batch.
        graph_size (int): Number of nodes in the graphs of the batch.
        clique_size_array (List[int]): Size of the planted clique in each graph of the batch.
        p_correction_type (str): Type of p correction to apply.
        input_magnification (bool): Whether the input needs to be magnified. If True, the graph will be made a 2400x2400 tensor.
        p_clique (float): Probability of a graph having a planted clique. Default is 0.5.
        p_nodes (float): Probability of an edge being present between two nodes. Default is 0.5.

    Returns:
        tuple: A tuple containing the batch of graphs and the corresponding on_off flags.
    """

    # Testing validity of input parameters:
    if number_of_graphs == 0:
        raise ValueError("At least one graph must be generated.")
    # - testing that number of graphs and clique size array length match:
    if len(clique_size_array) != number_of_graphs:
        raise ValueError(
            "The number of graphs must be the same of clique size array length"
        )
    # - testing that all values are positive integers:
    if (
        not all(
            isinstance(size, (int, np.int32, np.int64)) for size in clique_size_array
        )
        or any(size <= 0 for size in clique_size_array)
        or graph_size <= 0
    ):
        raise ValueError(
            "All clique size values and graph size value must be positive integers"
        )
    # - testing that the probability values are in the [0-1] range:
    elif (p_nodes <= 0 or p_nodes > 1) or (p_clique <= 0 or p_clique > 1):
        raise ValueError(
            "Probability of association between nodes and probability of the presence of a clique must be included in the range [0-1]"
        )

    # Generating the labels (with/without clique)
    on_off = torch.bernoulli(p_clique * torch.ones(number_of_graphs))
    # Generating the graph_list that will contain the adjacency matrices (now filled with zeros, will be filled with the actual adjacency matrices later on)
    # - magnified input (for all models except MLP):
    if input_magnification:
        graphs = torch.zeros(number_of_graphs, 1, 2400, 2400)
    # - standard input (for MLP):
    else:
        graphs = torch.zeros(number_of_graphs, 1, graph_size, graph_size)

    for i in range(number_of_graphs):
        graphs[i, 0] = generate_graph(
            on_off[i],
            graph_size,
            clique_size_array[i],
            p_correction_type,
            input_magnification,
            p_nodes,
        )

    # returning the generated graphs and the on_off flag
    return graphs, on_off.tolist()

# %% [markdown]
# # AMP algo definitions

# %%
save_mu = {}
save_L = {}
d=5

def mu(l):
  if l in save_mu:
    return save_mu[l]
  if (l == 1):
    save_mu.update({l: 1})
    return 1
  else:
    f=lambda x: norm.pdf(x)*p(mu(l-1)+x,l-1)
    val, err = integrate.quad(f, -15, 15)
    save_mu.update({l: val})
    return  val

def L(l):
  if l in save_L:
    return save_L[l]
  f=lambda x: norm.pdf(x)*(sum(mu(l)**p*x**p/math.factorial(p) for p in range(d)))**2
  val, err = integrate.quad(f, -15, 15)
  save_L.update({l: math.sqrt(val)})
  return  math.sqrt(val)

def p(z,l):
  if (l == 0):
    return 1
  else:
    return sum(mu(l)**p*z**p/math.factorial(p) for p in range(d))/L(l)
  
def CliqueMarginals(W,t,n,k):
  A = W/math.sqrt(n)  
  #A = W/k
  A.fill_diagonal_(0)
  zeta = torch.zeros(n)
  theta_ij_0 = torch.ones([n,n]).fill_diagonal_(0)
  theta_ij_1 = torch.zeros([n,n])
  theta_i = torch.ones(n)
  for j in range(t+1):
    theta_i = torch.sum(A*p(theta_ij_0,j), dim=0)
    theta_ij_1 = theta_i.repeat(n,1) - A*p(torch.transpose(theta_ij_0,1,0),j)
    theta_ij_0 = theta_ij_1.fill_diagonal_(0)
  return theta_i

def CliqueDecision(W,n,k,t=2,eps=0):
  x = CliqueMarginals(W,t,n,k)
  index = np.where(x > mu(t))[0]
  W_reduced = W[index[:, None], index]/np.sqrt(index.shape[0])
  eigenvalues_W = torch.linalg.eigvalsh(W_reduced)
  exists = np.any(np.array(eigenvalues_W) > 2 + eps)
  return int(exists)

# %% [markdown]
# # Test function (adapted)

# %%
# TEST FUNCTION
# read configuration file:
config = load_config(
    os.path.join("AMP_test_config.yml")
)  # CHANGE THIS TO PERFORM DIFFERENT EXPERIMENTS

# looping over the different graph sizes in the experiment:
for graph_size in config["graph_size_values"]:

    if graph_size == 100:
        continue

    # Create empty dictionaries for storing testing results:
    fraction_correct_results = {}  # Fraction correct for each clique size
    metrics_results = {}  # Metrics dictionary

    # Calculate max clique size (proportion of graph size):
    max_clique_size = int(
        config["testing_parameters"]["max_clique_size_proportion_test"] * graph_size
    )

    # Calculate array of clique sizes for all test curriculum
    # NOTE: if max clique size is smaller than the the number of test levels, use max clique size as the number of test levels
    clique_sizes = np.linspace(
        max_clique_size,
        1,
        num=min(max_clique_size, config["testing_parameters"]["clique_testing_levels"]),
    ).astype(int)

    # Loop for decreasing clique sizes
    for current_clique_size in clique_sizes:

        # Initialize fraction correct list, updated at each test iteration
        fraction_correct_list = []

        # Loop for testing iterations:
        for test_iter in range(config["testing_parameters"]["test_iterations"]):

            # Generate clique size value of each graph in the current batch
            clique_size_array_test = generate_batch_clique_sizes(
                np.array([current_clique_size]),
                config["testing_parameters"]["num_test"],
            )

            # Generate validation graphs
            test = generate_batch(
                config["testing_parameters"]["num_test"],
                graph_size,
                clique_size_array_test,
                config["p_correction_type"],
                False,
            )
            
            hard_output = torch.zeros([config["testing_parameters"]["num_test"]])
            
            for graph_index, graph in enumerate(test[0]):
                AMP_output = CliqueDecision(
                    graph.squeeze(), graph_size, current_clique_size
                )
                hard_output[graph_index] = AMP_output

            # updating fraction correct list with the accuracy of the current test iteration:
            fraction_correct_list.append(
                (hard_output == torch.Tensor(test[1])).sum().item()
                / (1.0 * config["testing_parameters"]["num_test"])
            )

        # Updating dictionary after all test iterations for current clique size have been completed:
        fraction_correct_results[current_clique_size] = round(
            sum(fraction_correct_list) / len(fraction_correct_list), 2
        )

        # Printing the size of the clique just tested and the corresponding test accuracy:
        print(
            "||| Completed testing for clique = ",
            current_clique_size,
            ". Average fraction correct on test set = ",
            round(sum(fraction_correct_list) / len(fraction_correct_list), 2),
        )
        print("|||===========================================================")

    # - notify completion of testing:
    print(f"| Finished testing AMP algo.")

    # Saving accuracy results in .csv file:
    # - defining file name and path:
    file_path = os.path.join(
        os.getcwd(), f"AMP-algo_N{graph_size}_fraction_correct.csv"
    )
    # - saving the dictionary as a .csv file:
    with open(file_path, "w") as file:
        writer = csv.writer(file)
        writer.writerow(["clique size", "fraction correct"])  # Add column labels
        for key, value in fraction_correct_results.items():
            writer.writerow([key, value])

    print(f"- AMP Results saved successfully for N = {graph_size}.")
# Out:
# Configuration file loaded successfully.
# ||| Completed testing for clique =  105 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  103 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  102 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  101 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  100 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  99 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  98 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  97 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  96 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  95 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  94 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  93 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  92 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  91 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  90 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  89 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  88 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  87 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  86 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  85 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  83 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  82 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  81 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  80 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  79 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  78 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  77 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  76 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  75 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  74 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  73 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  72 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  71 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  70 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  69 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  68 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  67 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  66 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  65 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  64 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  62 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  61 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  60 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  59 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  58 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  57 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  56 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  55 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  54 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  53 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  52 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  51 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  50 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  49 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  48 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  47 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  46 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  45 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  44 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  43 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  41 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  40 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  39 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  38 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  37 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  36 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  35 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  34 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  33 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  32 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  31 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  30 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  29 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  28 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  27 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  26 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  25 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  24 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  23 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  22 . Average fraction correct on test set =  0.92
# |||===========================================================
# ||| Completed testing for clique =  20 . Average fraction correct on test set =  0.81
# |||===========================================================
# ||| Completed testing for clique =  19 . Average fraction correct on test set =  0.76
# |||===========================================================
# ||| Completed testing for clique =  18 . Average fraction correct on test set =  0.68
# |||===========================================================
# ||| Completed testing for clique =  17 . Average fraction correct on test set =  0.62
# |||===========================================================
# ||| Completed testing for clique =  16 . Average fraction correct on test set =  0.56
# |||===========================================================
# ||| Completed testing for clique =  15 . Average fraction correct on test set =  0.56
# |||===========================================================
# ||| Completed testing for clique =  14 . Average fraction correct on test set =  0.5
# |||===========================================================
# ||| Completed testing for clique =  13 . Average fraction correct on test set =  0.53
# |||===========================================================
# ||| Completed testing for clique =  12 . Average fraction correct on test set =  0.5
# |||===========================================================
# ||| Completed testing for clique =  11 . Average fraction correct on test set =  0.51
# |||===========================================================
# ||| Completed testing for clique =  10 . Average fraction correct on test set =  0.51
# |||===========================================================
# ||| Completed testing for clique =  9 . Average fraction correct on test set =  0.52
# |||===========================================================
# ||| Completed testing for clique =  8 . Average fraction correct on test set =  0.49
# |||===========================================================
# ||| Completed testing for clique =  7 . Average fraction correct on test set =  0.48
# |||===========================================================
# ||| Completed testing for clique =  6 . Average fraction correct on test set =  0.5
# |||===========================================================
# ||| Completed testing for clique =  5 . Average fraction correct on test set =  0.47
# |||===========================================================
# ||| Completed testing for clique =  4 . Average fraction correct on test set =  0.5
# |||===========================================================
# ||| Completed testing for clique =  3 . Average fraction correct on test set =  0.49
# |||===========================================================
# ||| Completed testing for clique =  2 . Average fraction correct on test set =  0.53
# |||===========================================================
# ||| Completed testing for clique =  1 . Average fraction correct on test set =  0.56
# |||===========================================================
# | Finished testing AMP algo.
# - AMP Results saved successfully for N = 150.
# ||| Completed testing for clique =  140 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  138 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  137 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  135 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  134 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  132 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  131 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  130 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  128 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  127 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  125 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  124 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  123 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  121 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  120 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  118 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  117 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  116 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  114 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  113 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  111 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  110 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  109 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  107 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  106 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  104 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  103 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  102 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  100 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  99 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  97 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  96 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  95 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  93 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  92 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  90 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  89 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  88 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  86 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  85 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  83 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  82 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  81 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  79 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  78 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  76 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  75 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  74 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  72 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  71 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  69 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  68 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  66 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  65 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  64 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  62 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  61 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  59 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  58 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  57 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  55 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  54 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  52 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  51 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  50 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  48 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  47 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  45 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  44 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  43 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  41 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  40 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  38 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  37 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  36 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  34 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  33 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  31 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  30 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  29 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  27 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  26 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  24 . Average fraction correct on test set =  0.94
# |||===========================================================
# ||| Completed testing for clique =  23 . Average fraction correct on test set =  0.89
# |||===========================================================
# ||| Completed testing for clique =  22 . Average fraction correct on test set =  0.82
# |||===========================================================
# ||| Completed testing for clique =  20 . Average fraction correct on test set =  0.69
# |||===========================================================
# ||| Completed testing for clique =  19 . Average fraction correct on test set =  0.65
# |||===========================================================
# ||| Completed testing for clique =  17 . Average fraction correct on test set =  0.57
# |||===========================================================
# ||| Completed testing for clique =  16 . Average fraction correct on test set =  0.52
# |||===========================================================
# ||| Completed testing for clique =  15 . Average fraction correct on test set =  0.52
# |||===========================================================
# ||| Completed testing for clique =  13 . Average fraction correct on test set =  0.51
# |||===========================================================
# ||| Completed testing for clique =  12 . Average fraction correct on test set =  0.55
# |||===========================================================
# ||| Completed testing for clique =  10 . Average fraction correct on test set =  0.49
# |||===========================================================
# ||| Completed testing for clique =  9 . Average fraction correct on test set =  0.52
# |||===========================================================
# ||| Completed testing for clique =  8 . Average fraction correct on test set =  0.52
# |||===========================================================
# ||| Completed testing for clique =  6 . Average fraction correct on test set =  0.48
# |||===========================================================
# ||| Completed testing for clique =  5 . Average fraction correct on test set =  0.49
# |||===========================================================
# ||| Completed testing for clique =  3 . Average fraction correct on test set =  0.5
# |||===========================================================
# ||| Completed testing for clique =  2 . Average fraction correct on test set =  0.48
# |||===========================================================
# ||| Completed testing for clique =  1 . Average fraction correct on test set =  0.5
# |||===========================================================
# | Finished testing AMP algo.
# - AMP Results saved successfully for N = 200.
# ||| Completed testing for clique =  210 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  207 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  205 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  203 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  201 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  199 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  197 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  195 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  193 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  191 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  188 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  186 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  184 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  182 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  180 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  178 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  176 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  174 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  172 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  169 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  167 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  165 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  163 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  161 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  159 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  157 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  155 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  153 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  150 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  148 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  146 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  144 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  142 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  140 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  138 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  136 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  134 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  131 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  129 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  127 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  125 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  123 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  121 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  119 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  117 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  115 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  112 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  110 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  108 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  106 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  104 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  102 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  100 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  98 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  96 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  93 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  91 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  89 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  87 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  85 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  83 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  81 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  79 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  77 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  74 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  72 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  70 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  68 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  66 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  64 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  62 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  60 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  58 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  55 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  53 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  51 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  49 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  47 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  45 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  43 . Average fraction correct on test set =  1.0
# |||===========================================================
# ||| Completed testing for clique =  41 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  39 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  36 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  34 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  32 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  30 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  28 . Average fraction correct on test set =  0.93
# |||===========================================================
# ||| Completed testing for clique =  26 . Average fraction correct on test set =  0.86
# |||===========================================================
# ||| Completed testing for clique =  24 . Average fraction correct on test set =  0.77
# |||===========================================================
# ||| Completed testing for clique =  22 . Average fraction correct on test set =  0.66
# |||===========================================================
# ||| Completed testing for clique =  20 . Average fraction correct on test set =  0.58
# |||===========================================================
# ||| Completed testing for clique =  17 . Average fraction correct on test set =  0.53
# |||===========================================================
# ||| Completed testing for clique =  15 . Average fraction correct on test set =  0.52
# |||===========================================================
# ||| Completed testing for clique =  13 . Average fraction correct on test set =  0.49
# |||===========================================================
# ||| Completed testing for clique =  11 . Average fraction correct on test set =  0.49
# |||===========================================================
# ||| Completed testing for clique =  9 . Average fraction correct on test set =  0.47
# |||===========================================================
# ||| Completed testing for clique =  7 . Average fraction correct on test set =  0.51
# |||===========================================================
# ||| Completed testing for clique =  5 . Average fraction correct on test set =  0.47
# |||===========================================================
# ||| Completed testing for clique =  3 . Average fraction correct on test set =  0.5
# |||===========================================================
# ||| Completed testing for clique =  1 . Average fraction correct on test set =  0.53
# |||===========================================================
# | Finished testing AMP algo.
# - AMP Results saved successfully for N = 300.
# ||| Completed testing for clique =  280 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  277 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  274 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  271 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  268 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  265 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  263 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  260 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  257 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  254 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  251 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  249 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  246 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  243 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  240 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  237 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  234 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  232 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  229 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  226 . Average fraction correct on test set =  0.98
# |||===========================================================
# ...
# |||===========================================================
# ||| Completed testing for clique =  23 . Average fraction correct on test set =  0.53
# |||===========================================================
# ||| Completed testing for clique =  17 . Average fraction correct on test set =  0.52
# |||===========================================================
# ||| Completed testing for clique =  12 . Average fraction correct on test set =  0.51
# |||===========================================================
# ||| Completed testing for clique =  6 . Average fraction correct on test set =  0.47
# |||===========================================================
# ||| Completed testing for clique =  1 . Average fraction correct on test set =  0.49
# |||===========================================================
# | Finished testing AMP algo.
# - AMP Results saved successfully for N = 800.
# ||| Completed testing for clique =  840 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  831 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  823 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  814 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  806 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  797 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  789 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  780 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  772 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  763 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  755 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  746 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  738 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  729 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  721 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  712 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  704 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  695 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  687 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  678 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  670 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  662 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  653 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  645 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  636 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  628 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  619 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  611 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  602 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  594 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  585 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  577 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  568 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  560 . Average fraction correct on test set =  0.95
# |||===========================================================
# ||| Completed testing for clique =  551 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  543 . Average fraction correct on test set =  0.95
# |||===========================================================
# ||| Completed testing for clique =  534 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  526 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  517 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  509 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  501 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  492 . Average fraction correct on test set =  0.95
# |||===========================================================
# ||| Completed testing for clique =  484 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  475 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  467 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  458 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  450 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  441 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  433 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  424 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  416 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  407 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  399 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  390 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  382 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  373 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  365 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  356 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  348 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  339 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  331 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  323 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  314 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  306 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  297 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  289 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  280 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  272 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  263 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  255 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  246 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  238 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  229 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  221 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  212 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  204 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  195 . Average fraction correct on test set =  0.99
# |||===========================================================
# ||| Completed testing for clique =  187 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  178 . Average fraction correct on test set =  0.94
# |||===========================================================
# ||| Completed testing for clique =  170 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  162 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  153 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  145 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  136 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  128 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  119 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  111 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  102 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  94 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  85 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  77 . Average fraction correct on test set =  0.98
# |||===========================================================
# ||| Completed testing for clique =  68 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  60 . Average fraction correct on test set =  0.97
# |||===========================================================
# ||| Completed testing for clique =  51 . Average fraction correct on test set =  0.96
# |||===========================================================
# ||| Completed testing for clique =  43 . Average fraction correct on test set =  0.83
# |||===========================================================
# ||| Completed testing for clique =  34 . Average fraction correct on test set =  0.57
# |||===========================================================
# ||| Completed testing for clique =  26 . Average fraction correct on test set =  0.49
# |||===========================================================
# ||| Completed testing for clique =  17 . Average fraction correct on test set =  0.51
# |||===========================================================
# ||| Completed testing for clique =  9 . Average fraction correct on test set =  0.49
# |||===========================================================
# ||| Completed testing for clique =  1 . Average fraction correct on test set =  0.48
# |||===========================================================
# | Finished testing AMP algo.
# - AMP Results saved successfully for N = 1200.
